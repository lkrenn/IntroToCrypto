# %% [markdown]
# # Coinmarketcap API
#
# In this notebook, I will be exploring data from the coinmarketcap website. I will begin using the code given in their documentation, then start to explore what else I can do with the API

# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '4fc319f7-b594-425e-984b-dbfce19195bf',
}

session = requests.Session()
session.headers.update(headers)

response = session.get(url, params=parameters)
data = json.loads(response.text)
print(data)
# Out:
# {'status': {'timestamp': '2021-08-08T20:40:17.913Z', 'error_code': 0, 'error_message': None, 'elapsed': 12, 'credit_count': 1, 'notice': None, 'total_count': 5960}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 8934, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'arrington-xrp-capital', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures', 'galaxy-digital-portfolio', 'huobi-capital', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradig
# ...

# %%
data.keys()
# Out:
# dict_keys(['status', 'data'])

# %% [markdown]
# Let's put this into a DataFrame

# %%
data['data'][0].keys()
# Out:
# dict_keys(['id', 'name', 'symbol', 'slug', 'num_market_pairs', 'date_added', 'tags', 'max_supply', 'circulating_supply', 'total_supply', 'platform', 'cmc_rank', 'last_updated', 'quote'])

# %%
data['data'][0]
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'num_market_pairs': 8934,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channels',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'arrington-xrp-capital',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures',
#   'galaxy-digital-portfolio',
#   'huobi-capital',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-xzy-screener'],
# ...

# %%
res = pd.DataFrame(data['data'])
res
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8934
# 1  1027      Ethereum    ETH      ethereum              5633
# 2   825        Tether   USDT        tether             16519
# 3  1839  Binance Coin    BNB  binance-coin               538
# 4  2010       Cardano    ADA       cardano               283
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2017-10-01T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1  [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 2  [payments, stablecoin, stablecoin-asset-backed...           NaN
# 3  [marketplace, centralized-exchange, payments, ...  1.681370e+08
# 4  [mineable, dpos, pos, platform, research, smar...  4.500000e+10
#
# ...

# %%
res = res.set_index('cmc_rank')
res
# Out:
#             id          name symbol          slug  num_market_pairs  \
# cmc_rank
# 1            1       Bitcoin    BTC       bitcoin              8934
# 2         1027      Ethereum    ETH      ethereum              5633
# 3          825        Tether   USDT        tether             16519
# 4         1839  Binance Coin    BNB  binance-coin               538
# 5         2010       Cardano    ADA       cardano               283
#
#                         date_added  \
# cmc_rank
# 1         2013-04-28T00:00:00.000Z
# 2         2015-08-07T00:00:00.000Z
# 3         2015-02-25T00:00:00.000Z
# 4         2017-07-25T00:00:00.000Z
# 5         2017-10-01T00:00:00.000Z
#
#                                                        tags    max_supply  \
# cmc_rank
# 1         [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 2         [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 3         [payments, stablecoin, stablecoin-asset-backed...           NaN
# ...

# %% [markdown]
# Now, let's try some more coins:

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '4fc319f7-b594-425e-984b-dbfce19195bf',
}

session = requests.Session()
session.headers.update(headers)

response = session.get(url, params=parameters)
data = json.loads(response.text)

# %%
res = pd.DataFrame(data['data'])
res
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin              8934
# 1    1027      Ethereum    ETH      ethereum              5633
# 2     825        Tether   USDT        tether             16519
# 3    1839  Binance Coin    BNB  binance-coin               538
# 4    2010       Cardano    ADA       cardano               283
# ..    ...           ...    ...           ...               ...
# 495  2608       Mithril   MITH       mithril                28
# 496  2748          Oxen   OXEN          oxen                 7
# 497  8066     YIELD App    YLD     yield-app                12
# 498  6947       Valobit   VBIT       valobit                 9
# 499  3753    PlatonCoin   PLTC    platoncoin                 2
#
#                    date_added  \
# 0    2013-04-28T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2015-02-25T00:00:00.000Z
# 3    2017-07-25T00:00:00.000Z
# 4    2017-10-01T00:00:00.000Z
# ...
